# %% [markdown]
# # Lab01 - Busca Booleana

# %% [markdown]
# ## Indice invertido

# %% [markdown]
# O método a seguir permite construir um indice invertido.

# %%
import nltk as n

inverted_index = {}
def build_inverted_index(data):
    data["noticia"] = data.titulo + " " + data.conteudo
    for index, doc in data.iterrows():
        doc.noticia = doc.noticia.lower()
        words = [str(word) for word in n.word_tokenize(doc.noticia)]
        for word in words:
            inverted_index.setdefault(word, []).append(doc.idNoticia)

    return inverted_index

# %% [markdown]
# ## Implementação dos métodos de busca

# %% [markdown]
# Criando um método de busca genérico podendo receber pesquisas com apenas um termo, dois termos com *and* ou com *or*.

# %%
def search(term):
    term = n.word_tokenize(term)

    if len(term) == 1:
        return _search_one_term(term[0])
    elif len(term) == 3 and term[1].upper() == "AND":
        return _search_and(term[0], term[2])
    elif len(term) == 3 and term[1].upper() == "OR":
        return _search_or(term[0], term[2])

# %% [markdown]
# Método de busca com apenas um termo.

# %%
def _search_one_term(term):
    if inverted_index.has_key(term.lower()):
        return sorted(list(set(inverted_index[term.lower()])))
    else:
        return None

# %% [markdown]
# Metodo de busca *and* com apenas dois termos.

# %%
def _search_and(first_term, second_term):
    if inverted_index.has_key(first_term.lower()) and inverted_index.has_key(second_term.lower()):
        return sorted(list(set(inverted_index[first_term.lower()]) & set(inverted_index[second_term.lower()])))
    else:
        return None

# %% [markdown]
# Metodo de busca *or* com apenas dois termos.

# %%
def _search_or(first_term, second_term):
    if inverted_index.has_key(first_term.lower()) and inverted_index.has_key(second_term.lower()):
        return sorted(list(set(inverted_index[first_term.lower()]) | set(inverted_index[second_term.lower()])))
    elif inverted_index.has_key(first_term.lower()):
        return sorted(list(set(inverted_index[first_term.lower()])))
    elif inverted_index.has_key(second_term.lower()):
        return sorted(list(set(inverted_index[second_term.lower()])))
    else:
        return None

# %% [markdown]
# ## Importação do data-set

# %%
import pandas as p

data = p.read_csv("data-set/estadao_noticias_eleicao.csv", encoding = "utf-8")[:100]
data = data.replace(np.NAN, "")

content = data.titulo + " " + data.subTitulo + " " + data.conteudo
# content = content.fillna("")

tokenizer = RegexpTokenizer(r'\w+')
tokens_lists = content.apply(lambda text: tokenizer.tokenize(text.lower()))
stopword_ = stopwords.words('portuguese')
filtered_tokens = tokens_lists.apply(lambda tokens: [token for token in tokens if token not in stopword_])
tokens = [token for tokens_list in filtered_tokens for token in tokens_list]
print (tokens)
# Out:
# ['pt', 'espera', '30', 'mil', 'pessoas', 'festa', 'esplanada', 'objetivo', 'é', 'demonstrar', 'apoio', 'popular', 'dilma', 'tentar', 'reduzir', 'questionamentos', 'adversários', 'brasília', 'após', 'desgaste', 'provocado', 'lançamento', 'medidas', 'impopulares', 'anúncio', 'ministério', 'nomes', 'contestados', 'movimentos', 'sociais', 'surgimento', 'manifestações', 'pró', 'impeachment', 'pt', 'pretende', 'mobilizar', 'menos', '30', 'mil', 'pessoas', 'encher', 'esplanada', 'ministérios', 'tornar', 'posse', 'presidente', 'dilma', 'rousseff', 'grande', 'endosso', 'popular', 'segundo', 'mandato', 'petista', 'palácio', 'planalto', 'avaliação', 'é', 'mobilização', 'sociedade', 'civil', 'é', 'fundamental', 'mostrar', 'presidente', 'possui', 'legitimidade', 'apoio', 'popular', 'ajudaria', 'desencorajar', 'aventureiros', 'queiram', 'questionar', 'resultado', 'urnas', 'vai', 'ser', 'posse', 'caráter', 'marcadamente', 'político', 'sentido', 'disputa', 'festa', 'celebração', 'vitória', 'diz', 'gilberto', 'carvalho', 'ocupou', 'cargo', 'ministro', 'chefe', 'secretaria', 'geral', 'presidência', 'república', 'pouca', 'gente', 'menos', '10', 'mil', 'pessoas', 'é', 'convite', 'outro', 'lado', 'faça', 'provocação', 'botarmos', 'bem', 'gente', 'duvido', 'alguém', 'queira', 'fazer', 'qualquer', 'provocação', 'ginásio', 'nilson', 'nelson', 'centro', 'brasília', 'cedido', 'governo', 'distrito', 'federal', 'tornou', 'abrigo', 'militantes', 'deslocaram', '22', 'estados', 'volta', '10h30', 'desta', 'quarta', 'feira', 'local', 'praticamente', 'vazio', 'expectativa', '400', '500', 'ônibus', 'chegassem', 'longo', 'dia', 'caravanas', 'organizadas', 'pt', 'centrais', 'sindicais', 'alguns', 'casos', 'próprios', 'militantes', 'partido', 'informou', 'gastos', 'transporte', 'pessoas', 'realização', 'festa', 'contará', 'shows', 'sambista', 'alcione', 'rapper', 'gog', 'cantora', 'brasiliense', 'ellen', 'oléria', 'militância', 'pt', 'compareceu', 'peso', 'campanha', 'comparecendo', 'número', 'maior', 'agora', 'porque', 'muitas', 'pessoas', 'têm', 'condição', 'vir', 'afirma', 'gilberto', 'carvalho', 'otimista', 'festa', 'bonita', 'apoio', 'artesã', 'raimunda', 'edna', 'silva', '53', 'anos', 'saiu', 'macapá', 'sábado', 'passado', 'pegou', 'navio', 'rumo', 'belém', 'lá', 'seguiu', 'viagem', '36', 'horas', 'ônibus', 'terminou', '7', 'horas', 'quarta', 'feira', '31', 'vir', 'cá', 'questão', 'honra', 'porque', 'sei', 'vou', 'aplaudir', 'outra', 'mulher', 'outra', 'petista', 'presidência', 'república', 'diz', 'dilma', 'vai', 'precisar', 'gente', 'segundo', 'mandato', 'cantor', 'compositor', 'ronaldo', 'alcântara', '49', 'vitória', 'apertada', '2', 'º', 'turno', 'dilma', 'sobre', 'senador', 'aécio', 'neves', 'candidato', 'psdb', 'presidência', 'república', 'fez', 'militância', 'mobilizar', 'viajar', 'brasília', 'é', 'importante', 'estar', 'aqui', 'fortalecer', 'dilma', 'justifica', 'caravana', 'belém', 'reuniu', '45', 'pessoas', 'pagaram', 'cota', 'pessoal', 'r', '280', 'fretar', 'ônibus', 'bagagem', 'trouxeram', 'farinha', 'mandioca', 'dez', 'litros', 'açaí', 'erros', 'governo', 'presidente', 'dilma', 'todo', 'mundo', 'erra', 'erros', 'menores', 'governos', 'anteriores', 'fala', 'tanto', 'corrupção', 'petrobrás', 'esquecem', 'privatização', 'vale', 'diz', 'advogado', 'andrei', 'mantovani', '40', 'militantes', 'entrevistados', 'estado', 'compareceram', 'primeira', 'posse', 'dilma', '1', 'º', 'janeiro', '2011', 'chuva', 'quatro', 'anos', 'posse', 'dilma', 'primeiro', 'mandato', 'mobilizou', 'cerca', '30', 'mil', 'pessoas', 'enfrentaram', 'forte', 'chuva', 'esplanada', 'ministérios', 'dilma', 'obrigada', 'fazer', 'trajeto', 'congresso', 'capota', 'rolls', 'royce', 'fechada', 'deixou', 'parte', 'militância', 'frustrada', 'ocasião', 'marcou', 'despedida', 'ex', 'presidente', 'luiz', 'inácio', 'lula', 'silva', 'muitos', 'brasília', 'objetivo', 'despedir', 'após', 'transmitir', 'cargo', 'sucessora', 'recepcionar', 'chefes', 'estado', 'lula', 'desceu', 'rampa', 'palácio', 'plan ...

# %% [markdown]
# ## Chamada ao método de contrução de indice invertido

# %%
build_inverted_index(data)
print (inverted_index.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-3b829bd15777> in <module>()
# ----> 1 build_inverted_index(data)
#       2 print (inverted_index.keys())
#
# <ipython-input-21-caed2adb5d33> in build_inverted_index(data)
#       5     data["noticia"] = data.titulo + " " + data.conteudo
#       6     for index, doc in data.iterrows():
# ----> 7         doc.noticia = doc.noticia.lower()
#       8         words = [str(word) for word in n.word_tokenize(doc.noticia)]
#       9         for word in words:
#
# AttributeError: 'float' object has no attribute 'lower'

# %% [markdown]
# ## Sanity Check

# %%
assert len(search("Campina AND Grande")) == 12

# %%
assert len(search("Campina OR Grande")) == 1656

# %%
assert search("Campina AND Grande") == [1068, 1370, 1770, 1952, 1987, 2763, 2777, 2779, 4802, 5382, 5870, 6694]

# %% [markdown]
# Para validar um busca *or* podemos usar a seguinte propriedade de operação de conjuntos

# %% [markdown]
# ![OR](https://njadnrfof9.execute-api.us-east-1.amazonaws.com/prod/svg?tex=%7CA%5C%3A%5Ccup%5C%3AB%7C%5C%3A%3D%5C%3A%7CA%7C%5C%3A%2B%5C%3A%7CB%7C%5C%3A%5C%3A-%5C%3A%7CA%5Ccap%20B%7C)

# %%
assert len(search("Campina OR Grande")) == len(search("Campina")) + len(search("Grande")) - len(search("Campina AND Grande"))

# %% [markdown]
# ## Exemplos de execução

# %% [markdown]
# debate *AND* presidencial

# %%
assert len(search("debate AND presidencial")) == 201

# %% [markdown]
# debate *OR* presidencial

# %%
assert len(search("debate OR presidencial")) == 1770

# %% [markdown]
# presidenciáveis *AND* corruptos

# %%
assert len(search("presidenciáveis AND corruptos")) == 0

# %% [markdown]
# presidenciáveis *OR* corruptos

# %%
assert len(search("presidenciáveis OR corruptos")) == 164

# %% [markdown]
# Belo *OR* Horizonte

# %%
assert len(search("Belo OR Horizonte")) == 331

# %% [markdown]
# Belo *AND* Horizonte

# %%
assert len(search("Belo AND Horizonte")) == 242
